# %%
import numpy as np

# %%
np.random.seed(10)

# %%
arr = np.random.randint(0,100, size=(4,5))

# %%
arr
# Out:
# array([[ 9, 15, 64, 28, 89],
#        [93, 29,  8, 73,  0],
#        [40, 36, 16, 11, 54],
#        [88, 62, 33, 72, 78]])

# %%
np.sort(arr, axis=0)
# Out:
# array([[ 9, 15,  8, 11,  0],
#        [40, 29, 16, 28, 54],
#        [88, 36, 33, 72, 78],
#        [93, 62, 64, 73, 89]])

# %%
np.sort(arr)
# Out:
# array([[ 9, 15, 28, 64, 89],
#        [ 0,  8, 29, 73, 93],
#        [11, 16, 36, 40, 54],
#        [33, 62, 72, 78, 88]])

# %%
import matplotlib.pylab as plt

# %%
img_arr = plt.imread("./白色裙子.jpg")

# %%
plt.imshow(img_arr)

# %%
arr.shape
# Out:
# (4, 5)

# %%
arr.size
# Out:
# 20

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr[0]
# Out:
# array([ 9, 15, 64, 28, 89])

# %%
img_2 = np.concatenate((img_arr, img_arr, img_arr), axis=1)
img_3 = np.concatenate((img_2, img_2, img_2))
plt.imshow(img_3)

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
np.array([[1,2,3], [4,5,6]])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr = np.array([1,2,'hello'])

# %%
arr[0]
# Out:
# '1'

# %%
import matplotlib.pylab as plt

# %%
cat = plt.imread('./cat.jpg')

# %%
plt.imshow(cat)

# %%
plt.imshow(cat-100)

# %%
plt.imshow(cat*10)

# %%
np.linspace(1,100, 1000)
# Out:
# array([  1.        ,   1.0990991 ,   1.1981982 ,   1.2972973 ,
#          1.3963964 ,   1.4954955 ,   1.59459459,   1.69369369,
#          1.79279279,   1.89189189,   1.99099099,   2.09009009,
#          2.18918919,   2.28828829,   2.38738739,   2.48648649,
#          2.58558559,   2.68468468,   2.78378378,   2.88288288,
#          2.98198198,   3.08108108,   3.18018018,   3.27927928,
#          3.37837838,   3.47747748,   3.57657658,   3.67567568,
#          3.77477477,   3.87387387,   3.97297297,   4.07207207,
#          4.17117117,   4.27027027,   4.36936937,   4.46846847,
#          4.56756757,   4.66666667,   4.76576577,   4.86486486,
#          4.96396396,   5.06306306,   5.16216216,   5.26126126,
#          5.36036036,   5.45945946,   5.55855856,   5.65765766,
#          5.75675676,   5.85585586,   5.95495495,   6.05405405,
#          6.15315315,   6.25225225,   6.35135135,   6.45045045,
#          6.54954955,   6.64864865,   6.74774775,   6.84684685,
# ...

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.random.seed(10)
np.random.randint(1, 11, size=(2,3,4))
# Out:
# array([[[10,  5,  1,  2],
#         [10,  1,  2,  9],
#         [10,  1,  9,  7]],
#
#        [[ 5,  4,  1,  5],
#         [ 7,  9,  2,  9],
#         [ 5,  2,  4,  7]]])

# %%
arr=np.array(np.random.randint(1,11, size=(3,4)))
arr
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
arr.shape
# Out:
# (3, 4)

# %%
arr.size
# Out:
# 12

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
arr[1]
# Out:
# array([9, 9, 3, 7])

# %%
arr[0]
# Out:
# array([9, 6, 5, 8])

# %%
arr[1,1]
# Out:
# 9

# %%
arr[:,1]
# Out:
# array([6, 9, 9])

# %%
arr.reshape((2,6))
# Out:
# array([[9, 6, 5, 8, 9, 9],
#        [3, 7, 3, 9, 9, 7]])

# %%
arr.reshape(-1, 4)
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
img = np.concatenate((cat, cat, cat), axis=0)
img = np.concatenate((img, img, img), axis=1)
plt.imshow(img)

# %%
arr
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
arr.sum()
# Out:
# 84

# %%
arr.mean()
# Out:
# 7.0

# %%
np.min(arr)
# Out:
# 3

# %%
np.prod(arr)
# Out:
# 6249746160

# %%
np.inf
# Out:
# inf

# %%
np.median(arr)
# Out:
# 7.5

# %%
np.argmax(arr)
# Out:
# 0

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
np.log(np.exp(1))
# Out:
# 1.0

# %%
arr
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
n = np.sort(arr)

# %%
n
# Out:
# array([[5, 6, 8, 9],
#        [3, 7, 9, 9],
#        [3, 7, 9, 9]])

# %%
arr
# Out:
# array([[9, 6, 5, 8],
#        [9, 9, 3, 7],
#        [3, 9, 9, 7]])

# %%
n = np.sort(arr, axis=0)

# %%
n
# Out:
# array([[3, 6, 3, 7],
#        [9, 9, 5, 7],
#        [9, 9, 9, 8]])

# %%
n = np.sort(arr)

# %%
n
# Out:
# array([[5, 6, 8, 9],
#        [3, 7, 9, 9],
#        [3, 7, 9, 9]])

# %%
img
# Out:
# array([[[231, 186, 131],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 85,  43,  44]],
#
#        [[232, 187, 132],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 84,  42,  43]],
#
#        [[232, 187, 132],
#         [233, 188, 133],
#         [233, 188, 133],
#         ...,
#         [ 99,  53,  53],
#         [ 91,  47,  46],
#         [ 83,  41,  42]],
#
#        ...,
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [200, 120,  83],
#         ...,
#         [189,  99,  65],
#         [187,  97,  63],
#         [187,  97,  63]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
#         ...,
#         [188,  98,  64],
#         [186,  96,  62],
#         [188,  95,  62]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
# ...

# %%
img-100
# Out:
# array([[[131,  86,  31],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [241, 199, 200]],
#
#        [[132,  87,  32],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [240, 198, 199]],
#
#        [[132,  87,  32],
#         [133,  88,  33],
#         [133,  88,  33],
#         ...,
#         [255, 209, 209],
#         [247, 203, 202],
#         [239, 197, 198]],
#
#        ...,
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [100,  20, 239],
#         ...,
#         [ 89, 255, 221],
#         [ 87, 253, 219],
#         [ 87, 253, 219]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
#         ...,
#         [ 88, 254, 220],
#         [ 86, 252, 218],
#         [ 88, 251, 218]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
# ...

# %%
img - 1
# Out:
# array([[[230, 185, 130],
#         [231, 186, 131],
#         [232, 187, 132],
#         ...,
#         [ 99,  53,  53],
#         [ 91,  47,  46],
#         [ 84,  42,  43]],
#
#        [[231, 186, 131],
#         [231, 186, 131],
#         [232, 187, 132],
#         ...,
#         [ 99,  53,  53],
#         [ 91,  47,  46],
#         [ 83,  41,  42]],
#
#        [[231, 186, 131],
#         [232, 187, 132],
#         [232, 187, 132],
#         ...,
#         [ 98,  52,  52],
#         [ 90,  46,  45],
#         [ 82,  40,  41]],
#
#        ...,
#
#        [[198, 118,  81],
#         [198, 118,  81],
#         [199, 119,  82],
#         ...,
#         [188,  98,  64],
#         [186,  96,  62],
#         [186,  96,  62]],
#
#        [[198, 118,  81],
#         [198, 118,  81],
#         [198, 118,  81],
#         ...,
#         [187,  97,  63],
#         [185,  95,  61],
#         [187,  94,  61]],
#
#        [[198, 118,  81],
#         [198, 118,  81],
#         [198, 118,  81],
# ...

# %%
img
# Out:
# array([[[231, 186, 131],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 85,  43,  44]],
#
#        [[232, 187, 132],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 84,  42,  43]],
#
#        [[232, 187, 132],
#         [233, 188, 133],
#         [233, 188, 133],
#         ...,
#         [ 99,  53,  53],
#         [ 91,  47,  46],
#         [ 83,  41,  42]],
#
#        ...,
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [200, 120,  83],
#         ...,
#         [189,  99,  65],
#         [187,  97,  63],
#         [187,  97,  63]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
#         ...,
#         [188,  98,  64],
#         [186,  96,  62],
#         [188,  95,  62]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
# ...

# %%
img - 100
# Out:
# array([[[131,  86,  31],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [241, 199, 200]],
#
#        [[132,  87,  32],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [240, 198, 199]],
#
#        [[132,  87,  32],
#         [133,  88,  33],
#         [133,  88,  33],
#         ...,
#         [255, 209, 209],
#         [247, 203, 202],
#         [239, 197, 198]],
#
#        ...,
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [100,  20, 239],
#         ...,
#         [ 89, 255, 221],
#         [ 87, 253, 219],
#         [ 87, 253, 219]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
#         ...,
#         [ 88, 254, 220],
#         [ 86, 252, 218],
#         [ 88, 251, 218]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
# ...

# %%
img -100
# Out:
# array([[[131,  86,  31],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [241, 199, 200]],
#
#        [[132,  87,  32],
#         [132,  87,  32],
#         [133,  88,  33],
#         ...,
#         [  0, 210, 210],
#         [248, 204, 203],
#         [240, 198, 199]],
#
#        [[132,  87,  32],
#         [133,  88,  33],
#         [133,  88,  33],
#         ...,
#         [255, 209, 209],
#         [247, 203, 202],
#         [239, 197, 198]],
#
#        ...,
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [100,  20, 239],
#         ...,
#         [ 89, 255, 221],
#         [ 87, 253, 219],
#         [ 87, 253, 219]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
#         ...,
#         [ 88, 254, 220],
#         [ 86, 252, 218],
#         [ 88, 251, 218]],
#
#        [[ 99,  19, 238],
#         [ 99,  19, 238],
#         [ 99,  19, 238],
# ...

# %%
type((img - 100)[0,0,0])
# Out:
# numpy.uint8
